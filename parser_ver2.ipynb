# %%
import requests
import json
#import aiohttp
#import asyncio
from io import StringIO
from html.parser import HTMLParser
import pandas as pd
import time
from tqdm import tqdm

# %%
PATH = "files"

# %%
#claning text from html tags 

class MLStripper(HTMLParser):
    def __init__(self):
        super().__init__()
        self.reset()
        self.strict = False
        self.convert_charrefs = True
        self.text = StringIO()

    def handle_data(self, d):
        self.text.write(d)

    def get_data(self):
        return self.text.getvalue()


def strip_tags(html):
    s = MLStripper()
    if not html:
        return ""
    s.feed(html)
    return s.get_data()

# %%
class Parser:
    def __init__(self, text, area, per_page):
        self.text = "NAME: " + text
        self.area = area
        self.per_page = per_page

    def getPage(self, p=0):
        params = {
            'text': self.text,  # Текст фильтра. В имени должно быть слово "Аналитик"
            'area': self.area,  # Поиск ощуществляется по вакансиям города Москва
            'page': p,  # Индекс страницы поиска на HH
            'per_page': self.per_page  # Кол-во вакансий на 1 странице
        }

        req = requests.get('https://api.hh.ru/vacancies', params)  # Посылаем запрос к API
        data = req.content.decode()  # Декодируем его ответ, чтобы Кириллица отображалась корректно
        req.close()
        return data
    
    
    def process_key_skills(self, skills):
        return ", ".join([skill["name"] for skill in skills])

    def make_save_df(self, pages, name):
        df = self.make_df(pages)
        df.to_csv(name, index=False)
        
    def getPages(self, n_pages):
        urls = []
        snippets = []
        for i in range(n_pages):
            data = json.loads((self.getPage(i)))
            
            
            urls = urls + [elem["url"] for elem in data["items"]]
            snippets = snippets + [elem["snippet"] for elem in data["items"]]
        return urls, snippets

    def Parse(self, pages):
        urls, snippets = self.getPages(pages)
        # loop = asyncio.get_event_loop()
        # htmls = loop.run_until_complete(self.get(urls, loop))
        # loop.close()
        htmls = []
        for url in urls:
            req = requests.get(url)
            html = req.content.decode()
            req.close()
            htmls.append(html)
        htmls = [json.loads(elem) for elem in htmls]
        return htmls, snippets
    
    def make_df(self, pages):
        df = pd.DataFrame(columns=['id', 'name', 'skills', 'desc', 'experience', 'spec', "area","resp","req",
                                   "schedule","employment", "profarea_name","url",
                                   "address", "lat", "lng"],
                          index=range(pages * self.per_page))
        
        rows, snippets = self.Parse(pages)
        for i, row in enumerate(rows):
            df.iloc[i]["id"] = row["id"]
            df.iloc[i]["name"] = row["name"]
            df.iloc[i]["skills"] = self.process_key_skills(row["key_skills"])
            df.iloc[i]["desc"] = strip_tags(row["description"])
            df.iloc[i]["experience"] = row["experience"]["name"]
            df.iloc[i]["spec"] = self.process_key_skills(row["specializations"])
            df.iloc[i]["area"] = row["area"]["name"]
            df.iloc[i]["resp"] = strip_tags(snippets[i]["responsibility"])
            df.iloc[i]["req"] = strip_tags(snippets[i]["requirement"])
            df.iloc[i]["schedule"] = row["schedule"]['name']
            df.iloc[i]["employment"] = row["employment"]['name']
            df.iloc[i]["profarea_name"] = row["specializations"][0]["profarea_name"]
            df.iloc[i]["url"] = row["alternate_url"]
            df.iloc[i]["address"] = None if type(row["address"]) == type(None) else row["address"]["raw"]
            df.iloc[i]["lat"] = None if type(row["address"]) == type(None) else row["address"]["lat"]
            df.iloc[i]["lng"] = None if type(row["address"]) == type(None) else row["address"]["lng"]
            

        return df

# %%
m1 = Parser('Аналитик', 1, 3)

# %%
m1.make_df(1)
# Out:
#          id                                             name  \
# 0  44490685                          Младший аналитик данных
# 1  46424733  Corporate Development –Analyst / Junior Analyst
# 2  44940321                           Junior Product manager
#
#                                               skills  \
# 0  Python, Django Framework, Английский язык, Dat...
# 1  Corporate Finance, Business Analysis, Analytic...
# 2  Маркетинговый анализ, Сбор и анализ информации...
#
#                                                 desc          experience  \
# 0  Обязанности:  Решать практические NLP-задачи д...  От 1 года до 3 лет
# 1  Zigmund.Online is a leading fast-growing compa...  От 1 года до 3 лет
# 2  Привет! Если ты ждал знак, то вот он :) Гигант...  От 1 года до 3 лет
#
#                                                 spec    area  \
# 0                      Начальный уровень, Мало опыта  Москва
# 1  Бюджетирование и планирование, Планово-экономи...  Москва
# 2  Начальный уровень, Мало опыта, Менеджмент прод...  Москва
#
#                                                 resp  \
# 0  Решать практические NLP-задачи для русского яз...
# 1  Preparation and updating of the financial mode...
# 2  Для бизнеса - платформа для поиска линейных ис...
#
#                                                  req     schedule  \
# 0  Знание основ NLP (named entity recognition, in...  Полный день
# 1  Minimum 1 or 2 years of similar experience in ...  Полный день
# 2  Здравый смысл и желание работать головой, а не...  Полный день
#
#          employment                                      profarea_name  \
# 0  Полная занятость       Информационные технологии, интернет, телеком
# 1  Полная занятость  Бухгалтерия, управленческий учет, финансы пред...
# 2  Полная занятость                             Маркетинг, реклама, PR
#
#                               url                              address  \
# 0  https://hh.ru/vacancy/44490685                                 None
# 1  https://hh.ru/vacancy/46424733                                 None
# 2  https://hh.ru/vacancy/44940321  Москва, улица Ленинская Слобода, 19
#
#        lat      lng
# 0     None     None
# 1     None     None
# 2  55.7083  37.6528

# %%
class Df_Maker:
    def __init__(self, params):
        self.params = params
       
    def create_df(self):
        data = pd.DataFrame()
        for value in params:
            parsing = Parser(value['text'], value['area'], value['per_page'])
            sub_df = parsing.make_df(1)
            data = data.append(sub_df, ignore_index = True)
        return data

# %%
params = [{'text': 'Аналитик', 'area': 1, 'per_page': 3},
          {'text': 'data science', 'area': 1, 'per_page': 2}]

# %%
c = Df_Maker(params)

# %%
c.params
# Out:
# [{'text': 'Аналитик', 'area': 1, 'per_page': 3},
#  {'text': 'data science', 'area': 1, 'per_page': 2}]

# %%
c.create_df()
# Out:
#          id                                             name  \
# 0  44490685                          Младший аналитик данных
# 1  46424733  Corporate Development –Analyst / Junior Analyst
# 2  44940321                           Junior Product manager
# 3  46663886                   SQL Data Engineer/ CRM Analyst
# 4  45992609                            Senior Data Scientist
#
#                                               skills  \
# 0  Python, Django Framework, Английский язык, Dat...
# 1  Corporate Finance, Business Analysis, Analytic...
# 2  Маркетинговый анализ, Сбор и анализ информации...
# 3  SQL, Data Mining, Data Transformation, ETL, Go...
# 4  Tensorflow, Python, Machine Learning, Data Sci...
#
#                                                 desc          experience  \
# 0  Обязанности:  Решать практические NLP-задачи д...  От 1 года до 3 лет
# 1  Zigmund.Online is a leading fast-growing compa...  От 1 года до 3 лет
# 2  Привет! Если ты ждал знак, то вот он :) Гигант...  От 1 года до 3 лет
# 3  To further evolve our product and scale the bu...       От 3 до 6 лет
# 4  We are hiring an ambitious data scientist to t...       От 3 до 6 лет
#
#                                                 spec    area  \
# 0                      Начальный уровень, Мало опыта  Москва
# 1  Бюджетирование и планирование, Планово-экономи...  Москва
# 2  Начальный уровень, Мало опыта, Менеджмент прод...  Москва
# 3    Программирование, Разработка, Инженер, Стартапы  Москва
# 4             Программирование, Разработка, Аналитик  Москва
#
#                                                 resp  \
# 0  Решать практические NLP-задачи для русского яз...
# 1  Preparation and updating of the financial mode...
# 2  Для бизнеса - платформа для поиска линейных ис...
# 3  Constantly innovate on our overall data archit...
# 4  Designing and documenting data architecture at...
#
#                                                  req          schedule  \
# 0  Знание основ NLP (named entity recognition, in...       Полный день
# 1  Minimum 1 or 2 years of similar experience in ...       Полный день
# 2  Здравый смысл и желание работать головой, а не...       Полный день
# 3  A degree in Computer Science, Math, Statistics...  Удаленная работа
# 4  5+ years of professional experience as a data ...  Удаленная работа
#
#          employment                                      profarea_name  \
# 0  Полная занятость       Информационные технологии, интернет, телеком
# 1  Полная занятость  Бухгалтерия, управленческий учет, финансы пред...
# 2  Полная занятость                             Маркетинг, реклама, PR
# 3  Полная занятость       Информационные технологии, интернет, телеком
# 4  Полная занятость       Информационные технологии, интернет, телеком
#
#                               url                              address  \
# 0  https://hh.ru/vacancy/44490685                                 None
# 1  https://hh.ru/vacancy/46424733                                 None
# 2  https://hh.ru/vacancy/44940321  Москва, улица Ленинская Слобода, 19
# 3  https://hh.ru/vacancy/46663886                                 None
# 4  https://hh.ru/vacancy/45992609                                 None
#
#        lat      lng
# 0     None     None
# 1     None     None
# 2  55.7083  37.6528
# 3     None     None
# 4     None     None
